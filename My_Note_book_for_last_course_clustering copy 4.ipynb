# %%
import requests
from PIL import Image
url_image1 = 'https://www.flyporter.com/Content/Images/about_airport/Billy_Bishop_Toronto_City_Airport.jpg'
Toronto = Image.open(requests.get(url_image1, stream=True).raw)
Toronto
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=728x345 at 0x7F6180AC45C0>

# %%
from PIL import Image
url_image2 = 'https://media.architecturaldigest.com/photos/5c116b315ed1df490d899801/16:9/w_1280%2Cc_limit/An%2520aerial%2520view%2520of%2520Hudson%2520Yards-%2520courtesy%2520of%2520Related-Oxford%2520(1).jpg'
New_York = Image.open(requests.get(url_image2, stream=True).raw)
New_York
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F6180AC4F28>
